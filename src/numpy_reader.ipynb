# %%
import numpy as np
import matplotlib.pyplot as plt

# Replace 'path/to/your/array.npy' with the actual file path
file_path = '/root/catkin_ws/src/guide_dog/src/tmp/depth/0.npy'

# Load the array
array = np.load(file_path)

array = np.clip(array, None, 10000)

# Visualize the array
plt.imshow(array, cmap='viridis')  # 'cmap' specifies the colormap
plt.colorbar()  # Optionally add a colorbar to indicate the scale
plt.show()

print(array.shape)
# Out:
# (480, 640)
